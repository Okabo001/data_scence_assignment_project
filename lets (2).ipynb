# %%
data = pd.read_excel('/content/Book3.csv.xlsx')
data

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score
from joblib import dump


# Loading the data from the path file in my google drive
dataset = pd.read_excel('/content/Book3.csv.xlsx')
data


#  dataframe from my dataset in spreedsheet
data = {
    'Weather': ['Clear', 'Rainy', 'Foggy', 'Snowy', 'Clear', 'Foggy', 'Rainy', 'Snowy'],
    'Road_Conditions': ['Dry', 'Wet', 'Wet', 'Icy', 'Dry', 'Wet', 'Wet', 'Icy'],
    'Location': ['Nairobi Intersection', 'Mombasa Highway', 'Kisumu Residential', 'Nakuru Roundabout', 'Eldoret Intersection', 'Nyeri Residential', 'Thika Roundabout', 'Naivasha Highway'],
    'Time_of_Day': ['Morning', 'Afternoon', 'Evening', 'Night', 'Morning', 'Morning', 'Morning', 'Morning'],
    'Accident_Severity': [3.5, 2.2, 1.7, 4, 3.2, 1.5, 2.9, 4.2],
}

dataset = pd.DataFrame(data)

# here I try Encoding the categorical variables using one-hot encoding
encoder = OneHotEncoder(sparse=False, drop='first')
X_encoded = encoder.fit_transform(dataset[['Weather', 'Road_Conditions', 'Location', 'Time_of_Day']])

X_train, X_test, Y_train, Y_test = train_test_split(X_encoded, dataset['Accident_Severity'], test_size=0.2, random_state=42)

#  Training the linear regression model
model = LinearRegression()
model.fit(X_train, Y_train)

# Evaluating the model
Y_pred = model.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared (R^2): {r2}")

# Save the trained model
dump(model, 'accident_severity_model.joblib')

# %%
dataset = pd.read_excel('/content/Book3.csv.xlsx')
data
# Out:
#    Weather Road_Conditions               Location Time_of_Day  \
# 0    Clear             Dry   Nairobi Intersection     Morning
# 1    Rainy             Wet        Mombasa Highway   Afternoon
# 2    Foggy             Wet     Kisumu Residential     Evening
# 3    Snowy             Icy      Nakuru Roundabout       Night
# 4    Clear             Dry   Eldoret Intersection     Morning
# ..     ...             ...                    ...         ...
# 58   Clear             Dry  Marsabit Intersection     Evening
# 59   Snowy             Icy       Kisii Roundabout     Evening
# 60   Clear             Dry       Embu Residential     Evening
# 61   Rainy             Wet     Kapenguria Highway     Evening
# 62   Foggy             Wet  Homa Bay Intersection     Evening
#
#     Accident_Severity
# 0                 3.5
# 1                 2.2
# 2                 1.7
# 3                 4.0
# 4                 3.2
# ..                ...
# 58                3.4
# 59                4.3
# ...

# %%
data.describe()
# Out:
#        Accident_Severity
# count          63.000000
# mean            2.980952
# std             1.005927
# min             1.100000
# 25%             2.050000
# 50%             3.000000
# 75%             3.850000
# max             4.500000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Accident_Severity'].plot(kind='hist', bins=20, title='Accident_Severity')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Accident_Severity'].plot(kind='line', figsize=(8, 4), title='Accident_Severity')
# plt.gca().spines[['top', 'right']].set_visible(False)
